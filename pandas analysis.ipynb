# %%
import pandas as pd

# %%
df=pd.read_csv("d:/spyderpractice/weather.csv")
df.head()
# Out:
#    Id Country_Region Province_State        Date  ConfirmedCases  Fatalities  \
# 0   1    Afghanistan            NaN  2020-01-22             0.0         0.0
# 1   2    Afghanistan            NaN  2020-01-23             0.0         0.0
# 2   3    Afghanistan            NaN  2020-01-24             0.0         0.0
# 3   4    Afghanistan            NaN  2020-01-25             0.0         0.0
# 4   5    Afghanistan            NaN  2020-01-26             0.0         0.0
#
#   country+province   Lat  Long  day_from_jan_first  ...   min   max    stp  \
# 0     Afghanistan-  33.0  65.0                  22  ...  33.6  54.9  999.9
# 1     Afghanistan-  33.0  65.0                  23  ...  32.7  55.9  999.9
# 2     Afghanistan-  33.0  65.0                  24  ...  36.9  43.2  999.9
# 3     Afghanistan-  33.0  65.0                  25  ...  37.9  56.3  999.9
# 4     Afghanistan-  33.0  65.0                  26  ...  36.1  53.1  999.9
#
#       slp  dewp        rh        ah  wdsp   prcp  fog
# ...

# %%
df['min'].max()
# Out:
# 89.6

# %%
df['max'].max()
# Out:
# 113.2

# %%
df.describe()
# Out:
#                 Id  ConfirmedCases    Fatalities           Lat          Long  \
# count  24414.00000    24414.000000  24414.000000  24414.000000  24414.000000
# mean   17823.50000      835.249447     39.778201     24.359897      4.101068
# std    10300.68915     6554.109673    494.078524     23.619643     78.593946
# min        1.00000        0.000000      0.000000    -51.694444   -157.498300
# 25%     8912.25000        0.000000      0.000000     12.134722    -70.035800
# 50%    17823.50000        0.000000      0.000000     30.617100      9.550000
# 75%    26734.75000       75.000000      0.000000     41.902900     55.247100
# max    35646.00000   151061.000000  17669.000000     64.963100    178.450000
#
#        day_from_jan_first          temp           min           max  \
# count        24414.000000  24414.000000  24299.000000  24388.000000
# mean            60.500000     57.584509     48.455665     66.997486
# std             22.515271     22.115746     22.744141     21.984603
# ...

# %%
df.shape
# Out:
# (24414, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24414 entries, 0 to 24413
# Data columns (total 21 columns):
# Id                    24414 non-null int64
# Country_Region        24414 non-null object
# Province_State        10374 non-null object
# Date                  24414 non-null object
# ConfirmedCases        24414 non-null float64
# Fatalities            24414 non-null float64
# country+province      24414 non-null object
# Lat                   24414 non-null float64
# Long                  24414 non-null float64
# day_from_jan_first    24414 non-null int64
# temp                  24414 non-null float64
# min                   24299 non-null float64
# max                   24388 non-null float64
# stp                   24414 non-null float64
# slp                   14309 non-null float64
# dewp                  23786 non-null float64
# rh                    23786 non-null float64
# ah                    23786 non-null float64
# wdsp                  24414 non-null float64
# ...

# %%
df['Date'][df['Lat']==33]
# Out:
# 0        2020-01-22
# 1        2020-01-23
# 2        2020-01-24
# 3        2020-01-25
# 4        2020-01-26
#             ...
# 11227    2020-04-04
# 11228    2020-04-05
# 11229    2020-04-06
# 11230    2020-04-07
# 11231    2020-04-08
# Name: Date, Length: 156, dtype: object

# %%
df['Lat'].mean()
# Out:
# 24.359897376998582

# %%
df.isnull().sum()
# Out:
# Id                        0
# Country_Region            0
# Province_State        14040
# Date                      0
# ConfirmedCases            0
# Fatalities                0
# country+province          0
# Lat                       0
# Long                      0
# day_from_jan_first        0
# temp                      0
# min                     115
# max                      26
# stp                       0
# slp                   10105
# dewp                    628
# rh                      628
# ah                      628
# wdsp                      0
# prcp                      0
# fog                       0
# dtype: int64

# %%
df2=df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                    0
# Country_Region        0
# Province_State        0
# Date                  0
# ConfirmedCases        0
# Fatalities            0
# country+province      0
# Lat                   0
# Long                  0
# day_from_jan_first    0
# temp                  0
# min                   0
# max                   0
# stp                   0
# slp                   0
# dewp                  0
# rh                    0
# ah                    0
# wdsp                  0
# prcp                  0
# fog                   0
# dtype: int64

# %%
df.shape
# Out:
# (6812, 21)

# %%
rows,columns=df.shape

# %%
rows
# Out:
# 6812

# %%
columns
# Out:
# 21

# %%
df.tail(5)
# Out:
#           Id  Country_Region            Province_State        Date  \
# 23626  34499  United Kingdom                Montserrat  2020-04-01
# 23627  34500  United Kingdom                Montserrat  2020-04-02
# 23628  34501  United Kingdom                Montserrat  2020-04-03
# 23629  34502  United Kingdom                Montserrat  2020-04-04
# 23711  34620  United Kingdom  Turks and Caicos Islands  2020-04-08
#
#        ConfirmedCases  Fatalities                         country+province  \
# 23626             5.0         0.0                United Kingdom-Montserrat
# 23627             5.0         0.0                United Kingdom-Montserrat
# 23628             6.0         0.0                United Kingdom-Montserrat
# 23629             6.0         0.0                United Kingdom-Montserrat
# 23711             8.0         1.0  United Kingdom-Turks and Caicos Islands
#
#              Lat       Long  day_from_jan_first  ...   min   max   stp  \
# ...

# %%
df[2:5]
# Out:
#       Id Country_Region                Province_State        Date  \
# 626  915      Australia  Australian Capital Territory  2020-01-24
# 627  916      Australia  Australian Capital Territory  2020-01-25
# 628  917      Australia  Australian Capital Territory  2020-01-26
#
#      ConfirmedCases  Fatalities                        country+province  \
# 626             0.0         0.0  Australia-Australian Capital Territory
# 627             0.0         0.0  Australia-Australian Capital Territory
# 628             0.0         0.0  Australia-Australian Capital Territory
#
#          Lat      Long  day_from_jan_first  ...   min   max    stp     slp  \
# 626 -35.4735  149.0124                  24  ...  56.8  81.7  945.2  1010.9
# 627 -35.4735  149.0124                  25  ...  60.3  90.0  944.9  1010.5
# 628 -35.4735  149.0124                  26  ...  59.4  91.8  946.4  1012.1
#
#      dewp        rh        ah  wdsp  prcp  fog
# 626  49.7  0.454962  0.119475   5.3   0.0    0
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Country_Region', 'Province_State', 'Date', 'ConfirmedCases',
#        'Fatalities', 'country+province', 'Lat', 'Long', 'day_from_jan_first',
#        'temp', 'min', 'max', 'stp', 'slp', 'dewp', 'rh', 'ah', 'wdsp', 'prcp',
#        'fog'],
#       dtype='object')

# %%
df.Country_Region
# Out:
# 624           Australia
# 625           Australia
# 626           Australia
# 627           Australia
# 628           Australia
#               ...
# 23626    United Kingdom
# 23627    United Kingdom
# 23628    United Kingdom
# 23629    United Kingdom
# 23711    United Kingdom
# Name: Country_Region, Length: 6812, dtype: object

# %% [markdown]
# # max,min,mean,std(functions)

# %%
df[df.temp==df.temp.max()]
# Out:
#        Id Country_Region   Province_State        Date  ConfirmedCases  \
# 944  1377      Australia  South Australia  2020-01-30             0.0
#
#      Fatalities           country+province      Lat      Long  \
# 944         0.0  Australia-South Australia -34.9285  138.6007
#
#      day_from_jan_first  ...   min    max    stp     slp  dewp        rh  \
# 944                  30  ...  70.2  109.6  999.3  1005.2  43.5  0.156218
#
#            ah  wdsp  prcp  fog
# 944  0.057416   4.2   0.0    0
#
# [1 rows x 21 columns]

# %%
df[['Date','temp']][df.temp==df.temp.max()]
# Out:
#            Date  temp
# 944  2020-01-30  97.3

# %%
df.set_index('Id',inplace=True)

# %%
df
# Out:
#        Country_Region                Province_State        Date  \
# Id
# 913         Australia  Australian Capital Territory  2020-01-22
# 914         Australia  Australian Capital Territory  2020-01-23
# 915         Australia  Australian Capital Territory  2020-01-24
# 916         Australia  Australian Capital Territory  2020-01-25
# 917         Australia  Australian Capital Territory  2020-01-26
# ...               ...                           ...         ...
# 34499  United Kingdom                    Montserrat  2020-04-01
# 34500  United Kingdom                    Montserrat  2020-04-02
# 34501  United Kingdom                    Montserrat  2020-04-03
# 34502  United Kingdom                    Montserrat  2020-04-04
# 34620  United Kingdom      Turks and Caicos Islands  2020-04-08
#
#        ConfirmedCases  Fatalities                         country+province  \
# Id
# 913               0.0         0.0   Australia-Australian Capital Territory
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#          Id  Country_Region                Province_State        Date  \
# 0       913       Australia  Australian Capital Territory  2020-01-22
# 1       914       Australia  Australian Capital Territory  2020-01-23
# 2       915       Australia  Australian Capital Territory  2020-01-24
# 3       916       Australia  Australian Capital Territory  2020-01-25
# 4       917       Australia  Australian Capital Territory  2020-01-26
# ...     ...             ...                           ...         ...
# 6807  34499  United Kingdom                    Montserrat  2020-04-01
# 6808  34500  United Kingdom                    Montserrat  2020-04-02
# 6809  34501  United Kingdom                    Montserrat  2020-04-03
# 6810  34502  United Kingdom                    Montserrat  2020-04-04
# 6811  34620  United Kingdom      Turks and Caicos Islands  2020-04-08
#
#       ConfirmedCases  Fatalities                         country+province  \
# ...
